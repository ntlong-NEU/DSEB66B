# %% [markdown]
# ## Lectrue 5: Condition statements

# %%
bool([]) #empty set or tuple
# Out:
# False

# %%
bool([0])
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1.2) #non zero
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
age = int(input("enter your age: "))
price = 1000
if age <10:
    disount = 15
elif age <18:
   discount = 8
elif age <23:
    discount = 5
elif age <=60:
    discount = 2
else:
    discount = 25
print(f"your discount is {discount}%")
p = price*(100-discount)//100
print(f"you have to pay ${p}")
# Out:
# your discount is 2%
# you have to pay $980

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
age = int(input("How old are you?"))
gender = input("What is your gender(male or female)?")
gift = True 
price = 1000
if age < 10: 
    discount = 15 
elif age < 18: 
    discount = 8 
    if gender == "male": # gender.lower().strip() in {'f','m','female','male'}
        gift = False 
elif age < 23: 
    discount = 5
    if gender == "male": 
        gift = False 
elif age < 60: 
    discount = 2
    gift = False
else: 
    discount = 25 

p = price*(100-discount)//100
print(f"You get {discount}% and have to pay {p}$ and you have {int(gift)} gift.")
# Out:
# You get 5% and have to pay 950$ and you have 1 gift.
