# %% [markdown]
# ## Lectrue 5: Condition statements

# %%
bool([]) #empty set or tuple
# Out:
# False

# %%
bool([0])
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1.2) #non zero
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
age = int(input("enter your age: "))
price = 1000
if age <10:
    disount = 15
elif age <18:
   discount = 8
elif age <23:
    discount = 5
elif age <=60:
    discount = 2
else:
    discount = 25
print(f"your discount is {discount}%")
p = price*(100-discount)//100
print(f"you have to pay ${p}")
# Out:
# your discount is 2%
# you have to pay $980

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
age = int(input("How old are you?"))
gender = input("What is your gender(male or female)?")
gift = True 
price = 1000
if age < 10: 
    discount = 15 
elif age < 18: 
    discount = 8 
    if gender == "male": # gender.lower().strip() in {'f','m','female','male'}
        gift = False 
elif age < 23: 
    discount = 5
    if gender == "male": 
        gift = False 
elif age < 60: 
    discount = 2
    gift = False
else: 
    discount = 25 

p = price*(100-discount)//100
print(f"You get {discount}% and have to pay {p}$ and you have {int(gift)} gift.")
# Out:
# You get 5% and have to pay 950$ and you have 1 gift.

# %%
# list comprehesion
[i**2 for i in range(100) if i%5==0]
# Out:
# [0,
#  25,
#  100,
#  225,
#  400,
#  625,
#  900,
#  1225,
#  1600,
#  2025,
#  2500,
#  3025,
#  3600,
#  4225,
#  4900,
#  5625,
#  6400,
#  7225,
#  8100,
#  9025]

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
text = '''The Zen of Python, by Tim Peters

Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!'''

# %%
#normalize
text_nor = text.lower()
special_char = {',','.','*','-','!','?',';'}
for char in special_char:
    text_nor = text_nor.replace(char,' ')

# %%
words = text_nor.split()
print(words)
# Out:
# ['the', 'zen', 'of', 'python', 'by', 'tim', 'peters', 'beautiful', 'is', 'better', 'than', 'ugly', 'explicit', 'is', 'better', 'than', 'implicit', 'simple', 'is', 'better', 'than', 'complex', 'complex', 'is', 'better', 'than', 'complicated', 'flat', 'is', 'better', 'than', 'nested', 'sparse', 'is', 'better', 'than', 'dense', 'readability', 'counts', 'special', 'cases', "aren't", 'special', 'enough', 'to', 'break', 'the', 'rules', 'although', 'practicality', 'beats', 'purity', 'errors', 'should', 'never', 'pass', 'silently', 'unless', 'explicitly', 'silenced', 'in', 'the', 'face', 'of', 'ambiguity', 'refuse', 'the', 'temptation', 'to', 'guess', 'there', 'should', 'be', 'one', 'and', 'preferably', 'only', 'one', 'obvious', 'way', 'to', 'do', 'it', 'although', 'that', 'way', 'may', 'not', 'be', 'obvious', 'at', 'first', 'unless', "you're", 'dutch', 'now', 'is', 'better', 'than', 'never', 'although', 'never', 'is', 'often', 'better', 'than', 'right', 'now', 'if', 'the', 'implementation', 'is', 'hard', 'to', 'explain', "it's", 'a', 'bad', 'idea', 'if', 'the', 'implementation', 'is', 'easy', 'to', 'explain', 'it', 'may', 'be', 'a', 'good', 'idea', 'namespaces', 'are', 'one', 'honking', 'great', 'idea', "let's", 'do', 'more', 'of', 'those']

# %%
# count frequency
unique_words = set(words)
fre_words =[] 
for w in unique_words:
    fre_words.append((w,words.count(w)))

print(fre_words)
# Out:
# [('more', 1), ('right', 1), ('to', 5), ('first', 1), ('namespaces', 1), ('only', 1), ('good', 1), ('by', 1), ('great', 1), ('explain', 2), ('explicitly', 1), ('zen', 1), ('refuse', 1), ('bad', 1), ('idea', 3), ('do', 2), ('it', 2), ('peters', 1), ('are', 1), ('a', 2), ('special', 2), ("aren't", 1), ('break', 1), ('beats', 1), ("it's", 1), ('preferably', 1), ('dense', 1), ('be', 3), ('way', 2), ('face', 1), ('python', 1), ('implementation', 2), ('and', 1), ('errors', 1), ('pass', 1), ('of', 3), ('purity', 1), ('there', 1), ('simple', 1), ('ambiguity', 1), ('hard', 1), ('one', 3), ('may', 2), ('now', 2), ('practicality', 1), ('in', 1), ('easy', 1), ('often', 1), ('complicated', 1), ('at', 1), ('is', 10), ('sparse', 1), ('guess', 1), ('tim', 1), ('enough', 1), ('better', 8), ('honking', 1), ('those', 1), ('should', 2), ('counts', 1), ('silently', 1), ('that', 1), ('beautiful', 1), ('rules', 1), ('temptation', 1), ('obvious', 2), ('than', 8), ("let's", 1), ('not', 1), ('ugly', 1), ('if', 2), ('complex', 2), ('cases', 1), ('although', 3), ('implicit', 1), ('explicit', 1), ('nested', 1), ('readability', 1), ('the', 6), ("you're", 1), ('flat', 1), ('dutch', 1), ('unless', 2), ('never', 3), ('silenced', 1)]

# %%
import pandas as pd
pd.Series(dict(sorted(fre_words, key = lambda x: x[1], reverse= True))).plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# **3. Split a paragraph** of text into smaller paragraphs less than number_char = 61 characters in size and rejoin paragraphs by "\n\n". Note: The cutting point should be at the end of the sentence, except if not possible, leave it in the space position.
#
# + Input: "ChatGPT is    an AI assistant.\n\n It understands natural language.\n\n It helps answer    questions fast.\n\n It can assist with writing \n\ntasks.\n\n ChatGPT learns    from vast data.\n\nIt adapts to    user needs well.\n\n This AI     is by OpenAI's team.\n\n It's built to aid     and inform.\n\n Ask ChatGPT anything today!“
#
# + output: "ChatGPT is an AI assistant. It understands natural language.\n\n It helps answer questions fast.\n\n It can assist with writing tasks.\n\n ChatGPT learns from vast data.It adapts to user needs well.\n\n This AI is by OpenAI's team. It's built to aid and inform.\n\n Ask ChatGPT anything today!“

# %%
text_in = "ChatGPT is    an AI assistant.\n\n It understands natural language.\n\n It helps answer    questions fast.\n\n It can assist with writing \n\ntasks.\n\n ChatGPT learns    from vast data.\n\nIt adapts to    user needs well.\n\n This AI     is by OpenAI's team.\n\n It's built to aid     and inform.\n\n Ask ChatGPT anything today!"
print(text_in)
# Out:
# ChatGPT is    an AI assistant.
#
#  It understands natural language.
#
#  It helps answer    questions fast.
#
#  It can assist with writing
#
# tasks.
#
#  ChatGPT learns    from vast data.
#
# It adapts to    user needs well.
#
#  This AI     is by OpenAI's team.
#
#  It's built to aid     and inform.
#
#  Ask ChatGPT anything today!
